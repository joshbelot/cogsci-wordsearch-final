# %% [markdown]
# # Experiment B Notebook
#
# This notebook runs the part B experiment and saves the data. Part A is puzzle word scaling. This notebook will also generate new puzzles if they don't exist already.

# %% [markdown]
# ## Imports

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

# %%
import pandas as pd
import matplotlib
from tqdm import tqdm
from wordsearch.puzzle_sets import get_part_b
from wordsearch.strategies import (
    BruteForceStrategy,
    OrderedSearchStrategy,
    UncommonLetterSearchStrategy,
    RandomSampleStrategy,
    PatchSearchStrategy,
    RandomToOrderedStrategy
)

# %% [markdown]
# ## Puzzle Setup
# This will generate all the word searches needed if they don't already exist

# %%
puzzles = get_part_b()
# Out:
# Condition 'short' (5-5 letters): 200 generated, 0 failed
# Condition 'medium' (6-7 letters): 200 generated, 0 failed
# Condition 'long' (8-8 letters): 200 generated, 0 failed
#
# Part B total: 600 puzzles
# Part B saved.

# %% [markdown]
# ## Experiment Setup

# %%
strategies = [
    BruteForceStrategy(),
    OrderedSearchStrategy(),
    UncommonLetterSearchStrategy(),
    RandomSampleStrategy(max_attempts=5000),
    PatchSearchStrategy(),
    RandomToOrderedStrategy(),
]

# %% [markdown]
# # Run Experiments and Collect Data

# %%
rows = []

for condition, puzzle_list in puzzles.items():
    for i, puzzle in enumerate(tqdm(puzzle_list, desc=f"{condition:8s}", leave=True)):
        puzzle_id = f"B_{condition}_{i:04d}"
        word_lengths = [len(w) for w in puzzle.word_bank]
        avg_word_length = sum(word_lengths) / len(word_lengths)

        for strategy in strategies:
            result = strategy.solve(puzzle)

            rows.append({
                "puzzle_id":       puzzle_id,
                "strategy":        result.strategy_name,
                "condition":       condition,          # "short" / "medium" / "long"
                "size":            puzzle.size,        # always 30
                "word_count":      result.total_words,
                "avg_word_length": avg_word_length,
                "cells_examined":  result.cells_examined,
                "execution_time":  result.execution_time,
                "words_found":     result.words_found_count,
                "total_words":     result.total_words,
            })
# Out:
# short   : 100%|██████████| 200/200 [00:22<00:00,  8.92it/s]
# medium  : 100%|██████████| 200/200 [00:21<00:00,  9.35it/s]
# long    : 100%|██████████| 200/200 [00:20<00:00,  9.54it/s]

# %%
df_a = pd.DataFrame(rows)
print(f"\nTotal rows: {len(df_a):,}")
df_a.head()
# Out:
# Total rows: 3,600
#       puzzle_id                       strategy condition  size  word_count  \
# 0  B_short_0000                    Brute Force     short    30          16
# 1  B_short_0000                 Ordered Search     short    30          16
# 2  B_short_0000         Uncommon Letter Search     short    30          16
# 3  B_short_0000  Random Sample (attempts=5000)     short    30          16
# 4  B_short_0000                   Patch Search     short    30          16
#
#    avg_word_length  cells_examined  execution_time  words_found  total_words
# 0              5.0           58357        0.035584           16           16
# 1              5.0           48341        0.022094           16           16
# 2              5.0            1633        0.001062           16           16
# 3              5.0           58357        0.022897           16           16
# 4              5.0           58357        0.021985           16           16

# %%
df_a.to_csv('data/part_b/part_b_results.csv')
