# %%
from Wordsearch_Generator import Wordsearch, WordsearchGenerator

# %%
wg = WordsearchGenerator()

ws = wg.generate(10)

# %%
ws.display()
# Out:
# I T S E R T C W L A
# A E S U T O N O L K
# U E E K M S E N O H
# T M E D M I U O Y C
# V S N E T U O R D E
# R W E E K E N D O T
# O T W C D L T C V E
# G Y T I T N E A L S
# R A L U P O P I A S
# O O M I S S I O N A
#
# Word Bank:
# POPULAR, WEEKEND, MISSION, ENTITY, ASSET, LLOYD, VSNET
